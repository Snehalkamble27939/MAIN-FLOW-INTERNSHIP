# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import norm

# %%
dataframe = pd.read_csv("superstore.csv")

# %%
dataframe
# Out:
#               Category         City        Country Customer.ID  \
# 0      Office Supplies  Los Angeles  United States   LS-172304
# 1      Office Supplies  Los Angeles  United States   MV-174854
# 2      Office Supplies  Los Angeles  United States   CS-121304
# 3      Office Supplies  Los Angeles  United States   CS-121304
# 4      Office Supplies  Los Angeles  United States   AP-109154
# ...                ...          ...            ...         ...
# 51285  Office Supplies  Los Angeles  United States   AM-103604
# 51286  Office Supplies  Los Angeles  United States   AM-103604
# 51287  Office Supplies  Los Angeles  United States   HR-147704
# 51288  Office Supplies  Los Angeles  United States   RM-196754
# 51289  Office Supplies  Los Angeles  United States   FH-143654
#
#           Customer.Name  Discount Market  Order.Date        Order.ID  \
# 0      Lycoris Saunders       0.0     US  07-01-2011  CA-2011-130813
# ...

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 26 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Category        51290 non-null  object
#  1   City            51290 non-null  object
#  2   Country         51290 non-null  object
#  3   Customer.ID     51290 non-null  object
#  4   Customer.Name   51290 non-null  object
#  5   Discount        51290 non-null  float64
#  6   Market          51290 non-null  object
#  7   Order.Date      51290 non-null  object
#  8   Order.ID        51290 non-null  object
#  9   Order.Priority  51290 non-null  object
#  10  Product.ID      51290 non-null  object
#  11  Product.Name    51290 non-null  object
#  12  Profit          51290 non-null  float64
#  13  Quantity        51290 non-null  int64
#  14  Region          51290 non-null  object
#  15  Row.ID          51290 non-null  int64
#  16  Sales           51290 non-null  int64
# ...

# %%
dataframe.describe()
# Out:
#            Discount        Profit      Quantity       Row.ID         Sales  \
# count  51290.000000  51290.000000  51290.000000  51290.00000  51290.000000
# mean       0.142908     28.610982      3.476545  25645.50000    246.498440
# std        0.212280    174.340972      2.278766  14806.29199    487.567175
# min        0.000000  -6599.978000      1.000000      1.00000      0.000000
# 25%        0.000000      0.000000      2.000000  12823.25000     31.000000
# 50%        0.000000      9.240000      3.000000  25645.50000     85.000000
# 75%        0.200000     36.810000      5.000000  38467.75000    251.000000
# max        0.850000   8399.976000     14.000000  51290.00000  22638.000000
#
#        Shipping.Cost          Year       weeknum
# count   51290.000000  51290.000000  51290.000000
# mean       26.375818   2012.777208     31.287112
# std        57.296810      1.098931     14.429795
# min         0.002000   2011.000000      1.000000
# ...

# %%
dataframe.shape
# Out:
# (51290, 26)

# %%
dataframe.dtypes
# Out:
# Category           object
# City               object
# Country            object
# Customer.ID        object
# Customer.Name      object
# Discount          float64
# Market             object
# Order.Date         object
# Order.ID           object
# Order.Priority     object
# Product.ID         object
# Product.Name       object
# Profit            float64
# Quantity            int64
# Region             object
# Row.ID              int64
# Sales               int64
# Segment            object
# Ship.Date          object
# Ship.Mode          object
# Shipping.Cost     float64
# State              object
# Sub.Category       object
# Year                int64
# Market2            object
# weeknum             int64
# dtype: object

# %%
dataframe.head()
# Out:
#           Category         City        Country Customer.ID     Customer.Name  \
# 0  Office Supplies  Los Angeles  United States   LS-172304  Lycoris Saunders
# 1  Office Supplies  Los Angeles  United States   MV-174854     Mark Van Huff
# 2  Office Supplies  Los Angeles  United States   CS-121304      Chad Sievert
# 3  Office Supplies  Los Angeles  United States   CS-121304      Chad Sievert
# 4  Office Supplies  Los Angeles  United States   AP-109154    Arthur Prichep
#
#    Discount Market  Order.Date        Order.ID Order.Priority  ... Sales  \
# 0       0.0     US  07-01-2011  CA-2011-130813           High  ...    19
# 1       0.0     US  21-01-2011  CA-2011-148614         Medium  ...    19
# 2       0.0     US  05-08-2011  CA-2011-118962         Medium  ...    21
# 3       0.0     US  05-08-2011  CA-2011-118962         Medium  ...   111
# 4       0.0     US  29-09-2011  CA-2011-146969           High  ...     6
#
# ...

# %%
dataframe.tail()
# Out:
#               Category         City        Country Customer.ID  \
# 51285  Office Supplies  Los Angeles  United States   AM-103604
# 51286  Office Supplies  Los Angeles  United States   AM-103604
# 51287  Office Supplies  Los Angeles  United States   HR-147704
# 51288  Office Supplies  Los Angeles  United States   RM-196754
# 51289  Office Supplies  Los Angeles  United States   FH-143654
#
#         Customer.Name  Discount Market  Order.Date        Order.ID  \
# 51285  Alice McCarthy       0.2     US  03-12-2014  CA-2014-109701
# 51286  Alice McCarthy       0.2     US  03-12-2014  CA-2014-109701
# 51287  Hallie Redmond       0.2     US  18-12-2014  CA-2014-106964
# 51288   Robert Marley       0.2     US  25-12-2014  CA-2014-145219
# 51289    Fred Hopkins       0.2     US  26-12-2014  CA-2014-121398
#
#       Order.Priority  ... Sales      Segment   Ship.Date       Ship.Mode  \
# 51285           High  ...    69    Corporate  04-12-2014        Same Day
# ...

# %%
dataframe.isnull()
# Out:
#        Category   City  Country  Customer.ID  Customer.Name  Discount  Market  \
# 0         False  False    False        False          False     False   False
# 1         False  False    False        False          False     False   False
# 2         False  False    False        False          False     False   False
# 3         False  False    False        False          False     False   False
# 4         False  False    False        False          False     False   False
# ...         ...    ...      ...          ...            ...       ...     ...
# 51285     False  False    False        False          False     False   False
# 51286     False  False    False        False          False     False   False
# 51287     False  False    False        False          False     False   False
# 51288     False  False    False        False          False     False   False
# 51289     False  False    False        False          False     False   False
#
# ...

# %%
dataframe.notnull()
# Out:
#        Category  City  Country  Customer.ID  Customer.Name  Discount  Market  \
# 0          True  True     True         True           True      True    True
# 1          True  True     True         True           True      True    True
# 2          True  True     True         True           True      True    True
# 3          True  True     True         True           True      True    True
# 4          True  True     True         True           True      True    True
# ...         ...   ...      ...          ...            ...       ...     ...
# 51285      True  True     True         True           True      True    True
# 51286      True  True     True         True           True      True    True
# 51287      True  True     True         True           True      True    True
# 51288      True  True     True         True           True      True    True
# 51289      True  True     True         True           True      True    True
#
# ...

# %%
dataframe.isnull().sum()
# Out:
# Category          0
# City              0
# Country           0
# Customer.ID       0
# Customer.Name     0
# Discount          0
# Market            0
# Order.Date        0
# Order.ID          0
# Order.Priority    0
# Product.ID        0
# Product.Name      0
# Profit            0
# Quantity          0
# Region            0
# Row.ID            0
# Sales             0
# Segment           0
# Ship.Date         0
# Ship.Mode         0
# Shipping.Cost     0
# State             0
# Sub.Category      0
# Year              0
# Market2           0
# weeknum           0
# dtype: int64

# %%
dataframe.duplicated().sum()
# Out:
# 0

# %%
df_cleaned = dataframe.dropna()

# %%
df_cleaned
# Out:
#               Category         City        Country Customer.ID  \
# 0      Office Supplies  Los Angeles  United States   LS-172304
# 1      Office Supplies  Los Angeles  United States   MV-174854
# 2      Office Supplies  Los Angeles  United States   CS-121304
# 3      Office Supplies  Los Angeles  United States   CS-121304
# 4      Office Supplies  Los Angeles  United States   AP-109154
# ...                ...          ...            ...         ...
# 51285  Office Supplies  Los Angeles  United States   AM-103604
# 51286  Office Supplies  Los Angeles  United States   AM-103604
# 51287  Office Supplies  Los Angeles  United States   HR-147704
# 51288  Office Supplies  Los Angeles  United States   RM-196754
# 51289  Office Supplies  Los Angeles  United States   FH-143654
#
#           Customer.Name  Discount Market  Order.Date        Order.ID  \
# 0      Lycoris Saunders       0.0     US  07-01-2011  CA-2011-130813
# ...

# %%
dataframe.drop_duplicates()
# Out:
#               Category         City        Country Customer.ID  \
# 0      Office Supplies  Los Angeles  United States   LS-172304
# 1      Office Supplies  Los Angeles  United States   MV-174854
# 2      Office Supplies  Los Angeles  United States   CS-121304
# 3      Office Supplies  Los Angeles  United States   CS-121304
# 4      Office Supplies  Los Angeles  United States   AP-109154
# ...                ...          ...            ...         ...
# 51285  Office Supplies  Los Angeles  United States   AM-103604
# 51286  Office Supplies  Los Angeles  United States   AM-103604
# 51287  Office Supplies  Los Angeles  United States   HR-147704
# 51288  Office Supplies  Los Angeles  United States   RM-196754
# 51289  Office Supplies  Los Angeles  United States   FH-143654
#
#           Customer.Name  Discount Market  Order.Date        Order.ID  \
# 0      Lycoris Saunders       0.0     US  07-01-2011  CA-2011-130813
# ...

# %%
import numpy as np 
from scipy import stats

# %%
dataframe.columns
# Out:
# Index(['Category', 'City', 'Country', 'Customer.ID', 'Customer.Name',
#        'Discount', 'Market', 'Order.Date', 'Order.ID', 'Order.Priority',
#        'Product.ID', 'Product.Name', 'Profit', 'Quantity', 'Region', 'Row.ID',
#        'Sales', 'Segment', 'Ship.Date', 'Ship.Mode', 'Shipping.Cost', 'State',
#        'Sub.Category', 'Year', 'Market2', 'weeknum'],
#       dtype='object')

# %%
dataframe.drop(['Market2'], axis=1, inplace=True)
dataframe.columns
# Out:
# Index(['Category', 'City', 'Country', 'Customer.ID', 'Customer.Name',
#        'Discount', 'Market', 'Order.Date', 'Order.ID', 'Order.Priority',
#        'Product.ID', 'Product.Name', 'Profit', 'Quantity', 'Region', 'Row.ID',
#        'Sales', 'Segment', 'Ship.Date', 'Ship.Mode', 'Shipping.Cost', 'State',
#        'Sub.Category', 'Year', 'weeknum'],
#       dtype='object')

# %%
dataframe.head()
# Out:
#           Category         City        Country Customer.ID     Customer.Name  \
# 0  Office Supplies  Los Angeles  United States   LS-172304  Lycoris Saunders
# 1  Office Supplies  Los Angeles  United States   MV-174854     Mark Van Huff
# 2  Office Supplies  Los Angeles  United States   CS-121304      Chad Sievert
# 3  Office Supplies  Los Angeles  United States   CS-121304      Chad Sievert
# 4  Office Supplies  Los Angeles  United States   AP-109154    Arthur Prichep
#
#    Discount Market  Order.Date        Order.ID Order.Priority  ... Row.ID  \
# 0       0.0     US  07-01-2011  CA-2011-130813           High  ...  36624
# 1       0.0     US  21-01-2011  CA-2011-148614         Medium  ...  37033
# 2       0.0     US  05-08-2011  CA-2011-118962         Medium  ...  31468
# 3       0.0     US  05-08-2011  CA-2011-118962         Medium  ...  31469
# 4       0.0     US  29-09-2011  CA-2011-146969           High  ...  32440
#
# ...

# %%
data = [1, 2, 2, 2, 3, 1, 1, 15, 2, 2, 2, 3, 1, 1, 2]
mean = np.mean(data)
std = np.std(data)
print('mean of the dataset is', mean)
print('std. deviation is', std)
# Out:
# mean of the dataset is 2.6666666666666665
# std. deviation is 3.3598941782277745

# %%
threshold = 3
outlier = []
for i in data:
    z = (i-mean)/std
    if z > threshold:
        outlier.append(i)
print('outlier in dataset is', outlier)
# Out:
# outlier in dataset is [15]

# %%
data = [6, 2, 3, 4, 5, 1, 50]
sort_data = np.sort(data)
sort_data
# Out:
# array([ 1,  2,  3,  4,  5,  6, 50])

# %%
Q1 = np.percentile(data, 25, interpolation = 'midpoint') 
Q2 = np.percentile(data, 50, interpolation = 'midpoint') 
Q3 = np.percentile(data, 75, interpolation = 'midpoint') 

print('Q1 25 percentile of the given data is, ', Q1)
print('Q1 50 percentile of the given data is, ', Q2)
print('Q1 75 percentile of the given data is, ', Q3)

IQR = Q3 - Q1 
print('Interquartile range is', IQR)
# Out:
# Q1 25 percentile of the given data is,  2.5
# Q1 50 percentile of the given data is,  4.0
# Q1 75 percentile of the given data is,  5.5
# Interquartile range is 3.0

# %%
df = pd.DataFrame(data, columns=['weeknum'])

# Calculate descriptive statistics
mean_value = np.mean(data)           # Mean
median_value = np.median(data)       # Median
std_dev = np.std(data)               # Standard Deviation
variance_value = np.var(data)        # Variance

# Using Pandas (alternative)
mean_pandas = df['weeknum'].mean()
median_pandas = df['weeknum'].median()
std_pandas = df['weeknum'].std()
var_pandas = df['weeknum'].var()

# %%
mean_value
# Out:
# 10.142857142857142

# %%
median_value
# Out:
# 4.0

# %%
std_pandas
# Out:
# 17.65812911408012

# %%
var_pandas
# Out:
# 311.80952380952385

# %%
mean_pandas
# Out:
# 10.142857142857142

# %%
data = {
    'Sales': [19,19,21,111,6],
    'Shipping_cost': [4.37, 0.94, 1.81, 4.59, 1.32],
    'weeknum': [2, 4, 32, 32, 40]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Compute the correlation matrix
correlation_matrix = df.corr()

# Compute specific correlations
pearson_corr = df['Sales'].corr(df['Shipping_cost'], method='pearson')  # Pearson
spearman_corr = df['Sales'].corr(df['weeknum'], method='spearman')  # Spearman
kendall_corr = df['Shipping_cost'].corr(df['weeknum'], method='kendall')  # Kendall

# %%
continuous_columns = ['Sales','Quantity','Discount','Profit','Shipping Cost']

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, fmt='.2f', cmap='coolwarm')
plt.title('correlation matrix heatmap', fontsize=16)
plt.show()

# %%
sns.scatterplot(x=dataframe['Sales'], y=dataframe['Profit'])
plt.title("Sales vs Profit")
plt.xlabel("Sales")
plt.ylabel("Profit")
plt.show()

# %%
segment_analysis = dataframe.groupby('Segment')[['Sales', 'Profit']].mean()
sns.heatmap(segment_analysis, cmap='Reds', linecolor='Black', linewidth=.005)
# Out:
# <Axes: ylabel='Segment'>

# %%
correlation_matrix = dataframe[['Sales', 'Profit', 'Quantity', 'Discount', 'Shipping.Cost']].corr()
correlation_matrix
# Out:
#                   Sales    Profit  Quantity  Discount  Shipping.Cost
# Sales          1.000000  0.484923  0.313580 -0.086728       0.768075
# Profit         0.484923  1.000000  0.104365 -0.316490       0.354441
# Quantity       0.313580  0.104365  1.000000 -0.019875       0.272649
# Discount      -0.086728 -0.316490 -0.019875  1.000000      -0.079055
# Shipping.Cost  0.768075  0.354441  0.272649 -0.079055       1.000000

# %%
continuous_columns = ['Sales', 'Quantity', 'Discount', 'Profit', 'Shipping.Cost']

# Create boxplots for each continuous variable
for column in continuous_columns:
    plt.figure(figsize=(7, 5))
    sns.boxplot(x=dataframe[column])
    plt.title(f"Boxplot of {column}")
    plt.xlabel(column)
    plt.show()

# %%
df.describe()
# Out:
#             Sales  Shipping_cost    weeknum
# count    5.000000       5.000000   5.000000
# mean    35.200000       2.606000  22.000000
# std     42.792523       1.740037  17.663522
# min      6.000000       0.940000   2.000000
# 25%     19.000000       1.320000   4.000000
# 50%     19.000000       1.810000  32.000000
# 75%     21.000000       4.370000  32.000000
# max    111.000000       4.590000  40.000000

# %%
# Calculate Q1, Q3, and IQR
Q1 = df['Sales'].quantile(0.25)
Q3 = df['Sales'].quantile(0.75)
IQR = Q3 - Q1

# Define bounds
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Find outliers
iqr_outliers = dataframe[(dataframe['Sales'] < lower_bound) | (dataframe['Sales'] > upper_bound)]

print("Outliers in 'Sales' (using IQR Technique):")
iqr_outliers
# Out:
# Outliers in 'Sales' (using IQR Technique):
#               Category         City        Country Customer.ID  \
# 3      Office Supplies  Los Angeles  United States   CS-121304
# 4      Office Supplies  Los Angeles  United States   AP-109154
# 5      Office Supplies  Los Angeles  United States   JF-154904
# 7      Office Supplies  Los Angeles  United States   JA-159704
# 8      Office Supplies  Los Angeles  United States   SP-209204
# ...                ...          ...            ...         ...
# 51285  Office Supplies  Los Angeles  United States   AM-103604
# 51286  Office Supplies  Los Angeles  United States   AM-103604
# 51287  Office Supplies  Los Angeles  United States   HR-147704
# 51288  Office Supplies  Los Angeles  United States   RM-196754
# 51289  Office Supplies  Los Angeles  United States   FH-143654
#
#         Customer.Name  Discount Market  Order.Date        Order.ID  \
# 3        Chad Sievert       0.0     US  05-08-2011  CA-2011-118962
# ...

# %%
plt.figure(figsize=(8,5))

plt.hist(df.Sales, bins=20 , rwidth=.8 , density=True)
plt.xlabel('Sales', fontsize=18)
plt.ylabel('Probability Density' , fontsize=18)
# plt.xticks(fontsize=18)
# plt.yticks(fontsize=18)
plt.title('Bell Curve to show Normal Distribution of Sales', fontsize=18)

rng = np.arange(df['Sales'].min() , df['Sales'].max() , .1)
plt.plot(rng , norm.pdf(rng , df.Sales.mean() , df.Sales.std() ))

# %%
# Creating new column z-scores
dataframe['z-scores'] = (dataframe['Sales']  -  dataframe['Sales'].mean()) / dataframe['Sales'].std()

# Define bounds
lower_limit = dataframe['Sales'].mean() - 3*dataframe['Sales'].std()
upper_limit = dataframe['Sales'].mean() + 3*dataframe['Sales'].std()

# Find outliers
z_score_outliers = dataframe[(dataframe['Sales'] < lower_limit) | (dataframe['Sales'] > upper_limit)]

print("Outliers in 'Sales' (using Z-scores Technique):")
z_score_outliers
# Out:
# Outliers in 'Sales' (using Z-scores Technique):
#               Category           City        Country Customer.ID  \
# 361    Office Supplies  San Francisco  United States   KL-166454
# 417    Office Supplies  San Francisco  United States   EH-137654
# 663    Office Supplies        Burbank  United States   SC-200504
# 803    Office Supplies      Brentwood  United States   RW-195404
# 1137   Office Supplies  New York City  United States   JD-161504
# ...                ...            ...            ...         ...
# 51097       Technology    Los Angeles  United States   PS-190454
# 51116       Technology    Los Angeles  United States   RM-196754
# 51153       Technology    Los Angeles  United States   KF-162854
# 51173       Technology    Los Angeles  United States   GK-146204
# 51278  Office Supplies    Los Angeles  United States   ES-140204
#
#           Customer.Name  Discount Market  Order.Date        Order.ID  \
# ...

# %%
# Removing outliers
dataframe = dataframe[abs(dataframe['z-scores']) <= 3]
dataframe.head()
# Out:
#           Category         City        Country Customer.ID     Customer.Name  \
# 0  Office Supplies  Los Angeles  United States   LS-172304  Lycoris Saunders
# 1  Office Supplies  Los Angeles  United States   MV-174854     Mark Van Huff
# 2  Office Supplies  Los Angeles  United States   CS-121304      Chad Sievert
# 3  Office Supplies  Los Angeles  United States   CS-121304      Chad Sievert
# 4  Office Supplies  Los Angeles  United States   AP-109154    Arthur Prichep
#
#    Discount Market  Order.Date        Order.ID Order.Priority  ...   Segment  \
# 0       0.0     US  07-01-2011  CA-2011-130813           High  ...  Consumer
# 1       0.0     US  21-01-2011  CA-2011-148614         Medium  ...  Consumer
# 2       0.0     US  05-08-2011  CA-2011-118962         Medium  ...  Consumer
# 3       0.0     US  05-08-2011  CA-2011-118962         Medium  ...  Consumer
# 4       0.0     US  29-09-2011  CA-2011-146969           High  ...  Consumer
#
# ...

# %%
# Removing z-score column
dataframe = dataframe.drop('z-scores', axis=1)

# %%
dataframe
# Out:
#               Category         City        Country Customer.ID  \
# 0      Office Supplies  Los Angeles  United States   LS-172304
# 1      Office Supplies  Los Angeles  United States   MV-174854
# 2      Office Supplies  Los Angeles  United States   CS-121304
# 3      Office Supplies  Los Angeles  United States   CS-121304
# 4      Office Supplies  Los Angeles  United States   AP-109154
# ...                ...          ...            ...         ...
# 51285  Office Supplies  Los Angeles  United States   AM-103604
# 51286  Office Supplies  Los Angeles  United States   AM-103604
# 51287  Office Supplies  Los Angeles  United States   HR-147704
# 51288  Office Supplies  Los Angeles  United States   RM-196754
# 51289  Office Supplies  Los Angeles  United States   FH-143654
#
#           Customer.Name  Discount Market  Order.Date        Order.ID  \
# 0      Lycoris Saunders       0.0     US  07-01-2011  CA-2011-130813
# ...
